# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
EV=pd.read_csv("C:Electric_Vehicle_Population_Data.csv")
EV
# Out:
#         VIN (1-10)     County          City State  Postal Code  Model Year  \
# 0       5YJ3E1EA0K   Thurston      Tumwater    WA      98512.0        2019
# 1       1N4BZ1DV4N     Island       Clinton    WA      98236.0        2022
# 2       5YJ3E1EA0L  Snohomish     Snohomish    WA      98290.0        2020
# 3       5YJ3E1EBXL       King       Seattle    WA      98134.0        2020
# 4       5YJSA1CP0D  Snohomish       Edmonds    WA      98020.0        2013
# ...            ...        ...           ...   ...          ...         ...
# 135033  5YJSA1E29L       King  Yarrow Point    WA      98004.0        2020
# 135034  5YJYGDEE7M       King        Burien    WA      98168.0        2021
# 135035  5YJSA1E51N     Pierce    Gig Harbor    WA      98335.0        2022
# 135036  KM8KMDAF3P      Grant       Ephrata    WA      98823.0        2023
# 135037  1FADP5CU4E     Kitsap  Port Orchard    WA      98366.0        2014
#
#            Make    Model                   Electric Vehicle Type  \
# 0         TESLA  MODEL 3          Battery Electric Vehicle (BEV)
# 1        NISSAN     LEAF          Battery Electric Vehicle (BEV)
# 2         TESLA  MODEL 3          Battery Electric Vehicle (BEV)
# 3         TESLA  MODEL 3          Battery Electric Vehicle (BEV)
# 4         TESLA  MODEL S          Battery Electric Vehicle (BEV)
# ...         ...      ...                                     ...
# 135033    TESLA  MODEL S          Battery Electric Vehicle (BEV)
# 135034    TESLA  MODEL Y          Battery Electric Vehicle (BEV)
# 135035    TESLA  MODEL S          Battery Electric Vehicle (BEV)
# 135036  HYUNDAI  IONIQ 5          Battery Electric Vehicle (BEV)
# 135037     FORD    C-MAX  Plug-in Hybrid Electric Vehicle (PHEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0                 Clean Alternative Fuel Vehicle Eligible           220.0
# 1       Eligibility unknown as battery range has not b...             0.0
# 2                 Clean Alternative Fuel Vehicle Eligible           266.0
# 3                 Clean Alternative Fuel Vehicle Eligible           322.0
# 4                 Clean Alternative Fuel Vehicle Eligible           208.0
# ...                                                   ...             ...
# 135033            Clean Alternative Fuel Vehicle Eligible           330.0
# 135034  Eligibility unknown as battery range has not b...             0.0
# 135035  Eligibility unknown as battery range has not b...             0.0
# 135036  Eligibility unknown as battery range has not b...             0.0
# 135037              Not eligible due to low battery range            19.0
#
#         Base MSRP  Legislative District  DOL Vehicle ID  \
# 0             0.0                  22.0       242565116
# 1             0.0                  10.0       183272785
# 2             0.0                  44.0       112552366
# 3             0.0                  11.0         6336319
# 4         69900.0                  21.0       186212960
# ...           ...                   ...             ...
# 135033        0.0                  48.0       124776627
# 135034        0.0                  33.0       142857676
# 135035        0.0                  26.0       220157724
# 135036        0.0                  13.0       223872596
# 135037        0.0                  26.0       171102032
#
#                                       Vehicle Location  \
# 0        POINT (-122.91310169999997 47.01359260000004)
# 1        POINT (-122.35936399999997 47.97965520000008)
# 2        POINT (-122.09150499999998 47.91555500000004)
# 3       POINT (-122.32981499999994 47.579810000000066)
# 4                 POINT (-122.37507 47.80807000000004)
# ...                                                ...
# 135033   POINT (-122.20190499999995 47.61385000000007)
# 135034   POINT (-122.28645999999998 47.47613000000007)
# 135035   POINT (-122.58354539999999 47.32344880000005)
# 135036  POINT (-119.55512999999996 47.319360000000074)
# 135037   POINT (-122.63926499999997 47.53730000000007)
#
#                                          Electric Utility  2020 Census Tract
# 0                                  PUGET SOUND ENERGY INC       5.306701e+10
# 1                                  PUGET SOUND ENERGY INC       5.302997e+10
# 2                                  PUGET SOUND ENERGY INC       5.306105e+10
# 3            CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 4                                  PUGET SOUND ENERGY INC       5.306105e+10
# ...                                                   ...                ...
# 135033      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# 135034       CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303303e+10
# 135035  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...       5.305307e+10
# 135036                           PUD NO 2 OF GRANT COUNTY       5.302501e+10
# 135037                             PUGET SOUND ENERGY INC       5.303509e+10
#
# [135038 rows x 17 columns]

# %%
EV.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135038 entries, 0 to 135037
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         135038 non-null  object
#  1   County                                             135030 non-null  object
#  2   City                                               135030 non-null  object
#  3   State                                              135038 non-null  object
#  4   Postal Code                                        135030 non-null  float64
#  5   Model Year                                         135038 non-null  int64
#  6   Make                                               135038 non-null  object
#  7   Model                                              134789 non-null  object
#  8   Electric Vehicle Type                              135038 non-null  object
#  9   Clean Alternative Fuel Vehicle (CAFV) Eligibility  135038 non-null  object
#  10  Electric Range                                     135037 non-null  float64
#  11  Base MSRP                                          135037 non-null  float64
#  12  Legislative District                               134726 non-null  float64
#  13  DOL Vehicle ID                                     135038 non-null  int64
#  14  Vehicle Location                                   135028 non-null  object
#  15  Electric Utility                                   135030 non-null  object
#  16  2020 Census Tract                                  135030 non-null  float64
# dtypes: float64(5), int64(2), object(10)
# memory usage: 17.5+ MB

# %%
columns=EV.columns
columns
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
#        'Vehicle Location', 'Electric Utility', '2020 Census Tract'],
#       dtype='object')

# %%
EV.drop(columns=['VIN (1-10)','Base MSRP','Legislative District','DOL Vehicle ID','Vehicle Location','2020 Census Tract'],inplace=True)

# %%
EV.shape
# Out:
# (135038, 11)

# %%
EV.describe()
# Out:
#          Postal Code     Model Year  Electric Range
# count  135030.000000  135038.000000   135037.000000
# mean    98171.001577    2019.662880       74.591964
# std      2450.367211       3.001676       98.744120
# min      1730.000000    1997.000000        0.000000
# 25%     98052.000000    2018.000000        0.000000
# 50%     98121.000000    2021.000000       21.000000
# 75%     98370.000000    2022.000000      150.000000
# max     99701.000000    2024.000000      337.000000

# %%
EV.dtypes
# Out:
# County                                                object
# City                                                  object
# State                                                 object
# Postal Code                                          float64
# Model Year                                             int64
# Make                                                  object
# Model                                                 object
# Electric Vehicle Type                                 object
# Clean Alternative Fuel Vehicle (CAFV) Eligibility     object
# Electric Range                                       float64
# Electric Utility                                      object
# dtype: object

# %%
EV.isnull().sum()
# Out:
# County                                                 8
# City                                                   8
# State                                                  0
# Postal Code                                            8
# Model Year                                             0
# Make                                                   0
# Model                                                249
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         1
# Electric Utility                                       8
# dtype: int64

# %%
EV.head()
# Out:
#       County       City State  Postal Code  Model Year    Make    Model  \
# 0   Thurston   Tumwater    WA      98512.0        2019   TESLA  MODEL 3
# 1     Island    Clinton    WA      98236.0        2022  NISSAN     LEAF
# 2  Snohomish  Snohomish    WA      98290.0        2020   TESLA  MODEL 3
# 3       King    Seattle    WA      98134.0        2020   TESLA  MODEL 3
# 4  Snohomish    Edmonds    WA      98020.0        2013   TESLA  MODEL S
#
#             Electric Vehicle Type  \
# 0  Battery Electric Vehicle (BEV)
# 1  Battery Electric Vehicle (BEV)
# 2  Battery Electric Vehicle (BEV)
# 3  Battery Electric Vehicle (BEV)
# 4  Battery Electric Vehicle (BEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0            Clean Alternative Fuel Vehicle Eligible           220.0
# 1  Eligibility unknown as battery range has not b...             0.0
# 2            Clean Alternative Fuel Vehicle Eligible           266.0
# 3            Clean Alternative Fuel Vehicle Eligible           322.0
# 4            Clean Alternative Fuel Vehicle Eligible           208.0
#
#                                Electric Utility
# 0                        PUGET SOUND ENERGY INC
# 1                        PUGET SOUND ENERGY INC
# 2                        PUGET SOUND ENERGY INC
# 3  CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)
# 4                        PUGET SOUND ENERGY INC

# %%
EV['Model Year'].value_counts()
# Out:
# Model Year
# 2022    27983
# 2023    22476
# 2021    18554
# 2018    14343
# 2020    11151
# 2019    10577
# 2017     8579
# 2016     5688
# 2015     4925
# 2013     4598
# 2014     3601
# 2012     1657
# 2011      815
# 2024       30
# 2010       23
# 2008       20
# 2000        9
# 1999        4
# 2002        2
# 1998        1
# 2003        1
# 1997        1
# Name: count, dtype: int64

# %%
EV['Model Year'].value_counts().idxmax()
# Out:
# 2022

# %%
EV['Make'].value_counts().head(10)
# Out:
# Make
# TESLA         61808
# NISSAN        13150
# CHEVROLET     11437
# FORD           6897
# BMW            5895
# KIA            5491
# TOYOTA         4883
# VOLKSWAGEN     3526
# VOLVO          3221
# AUDI           2727
# Name: count, dtype: int64

# %%
EV['City'].value_counts().head(10)
# Out:
# City
# Seattle      23489
# Bellevue      6960
# Redmond       4965
# Vancouver     4819
# Kirkland      4201
# Bothell       4196
# Sammamish     3950
# Renton        3516
# Olympia       3228
# Tacoma        2846
# Name: count, dtype: int64

# %%
EV['County'].value_counts().head(10)
# Out:
# County
# King         70842
# Snohomish    15258
# Pierce       10410
# Clark         7997
# Thurston      4851
# Kitsap        4461
# Spokane       3326
# Whatcom       3315
# Benton        1688
# Skagit        1504
# Name: count, dtype: int64

# %%
EV['State'].value_counts().head(15)
# Out:
# State
# WA    134726
# CA        90
# VA        33
# MD        29
# TX        18
# NC        11
# CO        11
# AZ         9
# IL         7
# CT         7
# NY         6
# HI         6
# NV         6
# GA         6
# SC         6
# Name: count, dtype: int64

# %%
EV['Model'].value_counts().head(10)
# Out:
# Model
# MODEL 3        25837
# MODEL Y        23577
# LEAF           13020
# MODEL S         7473
# BOLT EV         5419
# VOLT            4881
# MODEL X         4874
# NIRO            2609
# ID.4            2480
# PRIUS PRIME     2473
# Name: count, dtype: int64

# %%
EV['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].value_counts()
# Out:
# Clean Alternative Fuel Vehicle (CAFV) Eligibility
# Clean Alternative Fuel Vehicle Eligible                         61221
# Eligibility unknown as battery range has not been researched    56983
# Not eligible due to low battery range                           16834
# Name: count, dtype: int64

# %%
EV['Electric Vehicle Type'].value_counts()
# Out:
# Electric Vehicle Type
# Battery Electric Vehicle (BEV)            103882
# Plug-in Hybrid Electric Vehicle (PHEV)     31156
# Name: count, dtype: int64

# %%
EV['Make'].unique()
# Out:
# array(['TESLA', 'NISSAN', 'BMW', 'AUDI', 'TOYOTA', 'KIA', 'FIAT', 'FORD',
#        'CHEVROLET', 'HYUNDAI', 'VOLVO', 'VOLKSWAGEN', 'CHRYSLER', 'SMART',
#        'RIVIAN', 'SUBARU', 'JEEP', 'HONDA', 'LINCOLN', 'LUCID', 'PORSCHE',
#        'MITSUBISHI', 'POLESTAR', 'MERCEDES-BENZ', 'MINI', 'JAGUAR',
#        'CADILLAC', 'LEXUS', 'GENESIS', 'WHEEGO ELECTRIC CARS', 'FISKER',
#        'MAZDA', 'BENTLEY', 'TH!NK', 'LAND ROVER', 'AZURE DYNAMICS'],
#       dtype=object)

# %%
print(EV['Electric Range'].max())
# Out:
# 337.0

# %%
df=EV.iloc[[EV['Electric Range'].idxmax()]]
df[['City', 'State', 'Postal Code', 'Model Year','Make', 'Model', 'Electric Vehicle Type',
    'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range','Electric Utility']]
# Out:
#         City State  Postal Code  Model Year   Make    Model  \
# 619  Belfair    WA      98528.0        2020  TESLA  MODEL S
#
#               Electric Vehicle Type  \
# 619  Battery Electric Vehicle (BEV)
#
#     Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 619           Clean Alternative Fuel Vehicle Eligible           337.0
#
#                                       Electric Utility
# 619  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...

# %%
EV['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].unique()
# Out:
# array(['Clean Alternative Fuel Vehicle Eligible',
#        'Eligibility unknown as battery range has not been researched',
#        'Not eligible due to low battery range'], dtype=object)

# %%
EV['Electric Vehicle Type'].unique()
# Out:
# array(['Battery Electric Vehicle (BEV)',
#        'Plug-in Hybrid Electric Vehicle (PHEV)'], dtype=object)

# %%
EV['Electric Range'].unique()
# Out:
# array([220.,   0., 266., 322., 208.,  97., 308.,  18.,  25., 151., 239.,
#        291.,  26.,  87., 215.,  84.,  19., 200.,  75.,  73.,  35.,  30.,
#         21., 150.,  14.,  29., 330.,  72.,  81., 126., 107.,  17., 238.,
#        249.,  76.,  38., 210.,  53., 293., 204., 103.,  16.,  83., 114.,
#        289.,  32.,  42., 259.,  13.,  58.,  82.,  20., 149.,  47., 125.,
#         22.,  33.,  41., 233.,  68.,   6., 192.,  12., 337.,  93.,  62.,
#         28.,  24., 234.,  15., 153.,  37.,  10., 265.,  31., 100., 258.,
#        110., 270., 222., 245.,  27., 218., 170.,  34.,  23., 111., 203.,
#          8.,   9., 124.,  40.,  48.,  95.,  74.,  36.,  51.,  39.,  57.,
#         56.,  nan,  11.,  59.])

# %%
category = [i for i in EV.columns if EV[i].dtype == 'object']
numerical = [i for i in EV.columns if EV[i].dtype != 'object']

# %%
EV[category].describe().T
# Out:
#                                                     count unique  \
# County                                             135030    169
# City                                               135030    651
# State                                              135038     46
# Make                                               135038     36
# Model                                              134789    125
# Electric Vehicle Type                              135038      2
# Clean Alternative Fuel Vehicle (CAFV) Eligibility  135038      3
# Electric Utility                                   135030     76
#
#                                                                                              top  \
# County                                                                                      King
# City                                                                                     Seattle
# State                                                                                         WA
# Make                                                                                       TESLA
# Model                                                                                    MODEL 3
# Electric Vehicle Type                                             Battery Electric Vehicle (BEV)
# Clean Alternative Fuel Vehicle (CAFV) Eligibility        Clean Alternative Fuel Vehicle Eligible
# Electric Utility                                   PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)
#
#                                                      freq
# County                                              70842
# City                                                23489
# State                                              134726
# Make                                                61808
# Model                                               25837
# Electric Vehicle Type                              103882
# Clean Alternative Fuel Vehicle (CAFV) Eligibility   61221
# Electric Utility                                    49369

# %%
EV[numerical].describe().T
# Out:
#                    count          mean          std     min      25%      50%  \
# Postal Code     135030.0  98171.001577  2450.367211  1730.0  98052.0  98121.0
# Model Year      135038.0   2019.662880     3.001676  1997.0   2018.0   2021.0
# Electric Range  135037.0     74.591964    98.744120     0.0      0.0     21.0
#
#                     75%      max
# Postal Code     98370.0  99701.0
# Model Year       2022.0   2024.0
# Electric Range    150.0    337.0

# %%
EV.duplicated().sum()
# Out:
# 92003

# %%
EV.columns[EV.isnull().any()]
# Out:
# Index(['County', 'City', 'Postal Code', 'Model', 'Electric Range',
#        'Electric Utility'],
#       dtype='object')

# %%
EV['Model Year'].unique()
# Out:
# array([2019, 2022, 2020, 2013, 2018, 2021, 2017, 2015, 2016, 2012, 2023,
#        2014, 2011, 2010, 2024, 2008, 2002, 1999, 1998, 2000, 2003, 1997],
#       dtype=int64)

# %%
plt.subplots(figsize=(12,6))
a=sns.countplot(data=EV,x='Model Year',order=EV['Model Year'].value_counts().index)
plt.show()

# %%
Car_Popularity = EV.value_counts(["Make","Model"],ascending=True).tail(10)
Car_Popularity
# Out:
# Make        Model
# TOYOTA      PRIUS PRIME     2473
# VOLKSWAGEN  ID.4            2480
# KIA         NIRO            2609
# TESLA       MODEL X         4874
# CHEVROLET   VOLT            4881
#             BOLT EV         5419
# TESLA       MODEL S         7473
# NISSAN      LEAF           13020
# TESLA       MODEL Y        23577
#             MODEL 3        25837
# Name: count, dtype: int64

# %%
Car_Popularity.plot(kind='barh',title = 'Car Model Popularity Graph',figsize=(20,10),
                             ylabel = "TOP 10 POPULAR MODELS", xlabel = "Total number of cars", fontsize = 15,color='lime')
plt.show()

# %%
CarsPerCounty = EV.value_counts(["County"],ascending=False).head(10)
CarsPerCounty
# Out:
# County
# King         70842
# Snohomish    15258
# Pierce       10410
# Clark         7997
# Thurston      4851
# Kitsap        4461
# Spokane       3326
# Whatcom       3315
# Benton        1688
# Skagit        1504
# Name: count, dtype: int64

# %%
CarsPerCounty.plot(kind='barh', title = 'Cars Per County Graph',figsize=(15,10),fontsize = 15,
                            ylabel = "County", xlabel = "Total number of cars",color='magenta')
plt.show()

# %%
CarsPerCityandCounty=EV.value_counts(['County','City'],ascending=False)
CarsPerCityandCounty
# Out:
# County       City
# King         Seattle       23489
#              Bellevue       6959
#              Redmond        4965
# Clark        Vancouver      4819
# King         Kirkland       4201
#                            ...
# Maricopa     Scottsdale        1
#              Goodyear          1
#              Chandler          1
#              Anthem            1
# Yellowstone  Billings          1
# Name: count, Length: 701, dtype: int64

# %%
CarsPerCityandCounty.head(15).plot(kind='barh',xlabel='Total number of Cars',ylabel='County and City',
                                   title='Cars Per City and County Graph',figsize=(15,10),fontsize=15,color='teal')
plt.show()

# %%
EV['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].value_counts().plot.pie(ylabel='Clean Alternative Fuel Vehicle (CAFV) Eligibility',autopct='%1.1f%%',colors=['c','m','b'],figsize=(15,10),fontsize=15)
plt.show()
